# %%
Graph[{1 \[UndirectedEdge] 2, 2 \[UndirectedEdge] 3, 
  3 \[UndirectedEdge] 1}]
# Out:
# Graph[<3>, <3>]

# %%
g = ExampleData[{"NetworkGraph", "ZacharyKarateClub"}];
FindGraphCommunities[g]
# Out:
# {{9, 26, 24, 25, 28, 29, 30, 27, 31, 32, 33, 15, 16, 19, 21, 23, 34},
#
# >   {2, 3, 4, 8, 10, 13, 14, 18, 22}, {1, 5, 6, 7, 11, 12, 17, 20}}

# %%
FindGraphCommunities[g]
# Out:
# {{9, 26, 24, 25, 28, 29, 30, 27, 31, 32, 33, 15, 16, 19, 21, 23, 34},
#
# >   {2, 3, 4, 8, 10, 13, 14, 18, 22}, {1, 5, 6, 7, 11, 12, 17, 20}}

# %%
FindGraphCommunities[g];
CommunityGraphPlot[g, %]
# Out:
# CommunityGraphPlot[Graph[<34>, <78>], Null]

# %%
CommunityGraphPlot[
 ExampleData[{"NetworkGraph", "DolphinSocialNetwork"}]]
# Out:
# -Graphics-
